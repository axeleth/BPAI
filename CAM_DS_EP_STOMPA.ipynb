# %% [markdown]
# <a href="https://colab.research.google.com/github/axeleth/BPAI/blob/main/CAM_DS_EP_STOMPA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")
# Out:
# Hello, World!
